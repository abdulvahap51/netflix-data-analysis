# %%
import numpy as np
import pandas as pn
import seaborn as sbs
import matplotlib.pyplot as plt

# %%
netflix=pn.read_csv('netflix_titles.csv')
netflix
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df=netflix.copy()
df.shape
# Out:
# (8807, 12)

# %%
df.tail()
# Out:
#      show_id     type        title         director
# 8802   s8803    Movie       Zodiac    David Fincher  \
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States  \
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration
# 8802  November 20, 2019          2007      R    158 min  \
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0  \
#
#                  max
# release_year  2021.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
tvshows = df[df['type'] == 'TV Show']

# %%
tvshows.head()
# Out:
#   show_id     type                  title         director
# 1      s2  TV Show          Blood & Water              NaN  \
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration
# 1  September 24, 2021          2021  TV-MA  2 Seasons  \
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sbs.countplot(data=df, x='type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Count of Movie Ratings')
plt.show()

# %%
sbs.catplot(x='type',y='release_year', data=df)

# %%
plt.figure(figsize=(10, 6)) 
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Ülkelerde Çekilen Filmler Dağılımı')
plt.axis('equal') 
plt.show()

# %%
rating_gruplar = df['rating'].value_counts(normalize=True) * 100
rating_gruplar
# Out:
# rating
# TV-MA       36.430762
# TV-14       24.537090
# TV-PG        9.803476
# R            9.076451
# PG-13        5.566284
# TV-Y7        3.794161
# TV-Y         3.487447
# PG           3.260252
# TV-G         2.499148
# NR           0.908781
# G            0.465750
# TV-Y7-FV     0.068159
# NC-17        0.034079
# UR           0.034079
# 74 min       0.011360
# 84 min       0.011360
# 66 min       0.011360
# Name: proportion, dtype: float64

# %%
rating_gruplar = df['rating'].value_counts(normalize=True) * 100


esik = 2.0
diger_oran = rating_gruplar[rating_gruplar < esik].sum()
rating_gruplar = rating_gruplar[rating_gruplar >= esik]
rating_gruplar['Diğer'] = diger_oran


plt.figure(figsize=(10, 6))
rating_gruplar.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Rating Değerlerine Göre Filmler Dağılımı')
plt.axis('equal')
plt.show()

# %%
rating_gruplar = df['country'].value_counts(normalize=True) * 100


esik = 1
diger_oran = rating_gruplar[rating_gruplar < esik].sum()
rating_gruplar = rating_gruplar[rating_gruplar >= esik]
rating_gruplar['Diğer'] = diger_oran


plt.figure(figsize=(20, 15))
rating_gruplar.plot(kind='pie', autopct='%1.1f%%', startangle=240)
plt.title('ulke Değerlerine Göre Filmler Dağılımı')
plt.axis('equal')
plt.show()

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
# "cast" sütunundaki oyuncuları ayırarak birden çok oyuncuyu ayrı ayrı ele alın
oyuncular_listesi = df['cast'].str.split(', ').explode()

# Oyuncuların sayısını hesaplayın
en_cok_oyuncu = oyuncular_listesi.value_counts().head(1)

# En çok filmde oynayan oyuncunun bilgilerini alın
en_cok_oyuncu_ad = en_cok_oyuncu.index[0]
en_cok_oyuncu_sayi = en_cok_oyuncu.values[0]

print(f"En çok filmde oynayan oyuncu: {en_cok_oyuncu_ad} ({en_cok_oyuncu_sayi} film)")
# Out:
# En çok filmde oynayan oyuncu: Anupam Kher (43 film)

# %%
oyuncular_listesi.value_counts().head(1)
# Out:
# cast
# Anupam Kher    43
# Name: count, dtype: int64

# %%
oyuncular_listesi
# Out:
# 0                         NaN
# 1                  Ama Qamata
# 1                 Khosi Ngema
# 1               Gail Mabalane
# 1              Thabang Molaba
#                 ...
# 8806         Manish Chaudhary
# 8806             Meghna Malik
# 8806            Malkeet Rauni
# 8806           Anita Shabdish
# 8806    Chittaranjan Tripathy
# Name: cast, Length: 64951, dtype: object

# %%
oyuncular_listesi.value_counts()
# Out:
# cast
# Anupam Kher                43
# Shah Rukh Khan             35
# Julie Tejwani              33
# Naseeruddin Shah           32
# Takahiro Sakurai           32
#                            ..
# Maryam Zaree                1
# Melanie Straub              1
# Gabriela Maria Schmeide     1
# Helena Zengel               1
# Chittaranjan Tripathy       1
# Name: count, Length: 36439, dtype: int64

# %%
len(oyuncular_listesi.value_counts()
)
# Out:
# 36439

# %%
oyuncular_listesi.value_counts().head(20)
# Out:
# cast
# Anupam Kher          43
# Shah Rukh Khan       35
# Julie Tejwani        33
# Naseeruddin Shah     32
# Takahiro Sakurai     32
# Rupa Bhimani         31
# Akshay Kumar         30
# Om Puri              30
# Yuki Kaji            29
# Paresh Rawal         28
# Amitabh Bachchan     28
# Boman Irani          27
# Rajesh Kava          26
# Vincent Tong         26
# Andrea Libman        25
# Kareena Kapoor       25
# Samuel L. Jackson    24
# John Cleese          24
# Fred Tatasciore      23
# Jigna Bhardwaj       23
# Name: count, dtype: int64

# %%
tvshows['duration'].value_counts()
# Out:
# duration
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# 13 Seasons       3
# 15 Seasons       2
# 12 Seasons       2
# 11 Seasons       2
# 17 Seasons       1
# Name: count, dtype: int64

# %%
tvshows['duration'].value_counts().sum()
# Out:
# 2676

# %%
1793/2676*100
# Out:
# 67.00298953662183

# %%
#bir dizinin 1 sezonda bitme olasılığı yüzde 67

# %%
df['date_added']
# Out:
# 0       September 25, 2021
# 1       September 24, 2021
# 2       September 24, 2021
# 3       September 24, 2021
# 4       September 24, 2021
#                ...
# 8802     November 20, 2019
# 8803          July 1, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 8807, dtype: object

# %%
df['date_added'] = pn.to_datetime(df['date_added'],errors='coerce')

# %%
df['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
sonraki_filmler = df[df['date_added'].dt.year >= 2021]
sonraki_filmler
# Out:
#      show_id     type                                           title
# 0         s1    Movie                            Dick Johnson Is Dead  \
# 1         s2  TV Show                                   Blood & Water
# 2         s3  TV Show                                       Ganglands
# 3         s4  TV Show                           Jailbirds New Orleans
# 4         s5  TV Show                                    Kota Factory
# ...      ...      ...                                             ...
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8437   s8438  TV Show                          The Netflix Afterparty
# 8461   s8462    Movie                               The Polar Express
#
#              director                                               cast
# ...

# %%
len(sonraki_filmler)
# Out:
# 1498

# %%
genre_counts = df['listed_in'].str.split(', ').explode().value_counts()

# Plot the count of genres using a bar plot
plt.figure(figsize=(10, 6))
sbs.barplot(x=genre_counts.index, y=genre_counts.values)
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Count of Genres')
plt.xticks(rotation=90, ha='center')
plt.show()

# %%
from wordcloud import WordCloud
dr_count = df['director'].value_counts()

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dr_count)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Movie Names Word Cloud')
plt.show()

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64
